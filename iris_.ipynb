# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekjot786/python/blob/main/iris_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv("Iris.csv")
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Load the Iris dataset using seaborn or sklearn. Display the first five rows of
# the dataset.
import seaborn as sns

iris_df = sns.load_dataset('iris')
display(iris_df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['petal_length'].plot(kind='hist', bins=20, title='petal_length')
# ...

# %%
species_counts.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Count of each Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(iris_df, hue='species')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(x='species', y='petal_length', data=iris_df)
plt.title('Violin Plot of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Get unique species
species = iris_df['species'].unique()

# Define colors for each species (you can customize this list)
colors = ['blue', 'green', 'red']

plt.figure(figsize=(8, 6))

for i, s in enumerate(species):
    subset = iris_df[iris_df['species'] == s]
    plt.scatter(subset['petal_width'], subset['petal_length'], c=colors[i], label=s)

plt.title('Petal Length vs Petal Width by Species')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()

# %%
sns.histplot(df['SepalLengthCm'], bins=15, kde=True, color='lightblue')
plt.title('Sepal Length Distribution')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.savefig('histogram_sepal_length.png')
plt.show()

# %%
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

for feature in features:
    plt.figure(figsize=(8,5))
    sns.boxplot(x='Species', y=feature, data=df)
    plt.title(f'Boxplot of {feature} by Species')
    plt.xlabel("Species")
    plt.ylabel(feature)
    plt.show()

# %%
print("""
Interpretation:
- Setosa species are well separated with small petal lengths.
- Versicolor and Virginica overlap slightly but can be separated by petal length & width.
- Petal features are more useful for classification than sepal features.
""")
# Out:
# Interpretation:
# - Setosa species are well separated with small petal lengths.
# - Versicolor and Virginica overlap slightly but can be separated by petal length & width.
# - Petal features are more useful for classification than sepal features.
